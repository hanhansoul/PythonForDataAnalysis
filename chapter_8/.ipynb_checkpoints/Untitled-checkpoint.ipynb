# %% [markdown]
# # 组合与合并数据集
#
# - `pandas.merge`：根据`DataFrame`的一个或多个键对行进行连接操作，类似于SQL中的join语句。
# - `pandas.concat`：将一个或多个`DataFrame`或`Series`按坐标轴方向拼接起来。
#
# ## `DataFrame`的数据库类型join操作

# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.DataFrame({'key': ['b', 'b', 'a', 'c', 'a', 'a', 'b'],
                    'data1': range(7)})
df1
# Out:
#    data1 key
# 0      0   b
# 1      1   b
# 2      2   a
# 3      3   c
# 4      4   a
# 5      5   a
# 6      6   b

# %%
df2 = pd.DataFrame({'key': ['a', 'b', 'd'],
                    'data2': range(3)})
df2
# Out:
#    data2 key
# 0      0   a
# 1      1   b
# 2      2   d

# %%
# inner join
pd.merge(df1, df2)
# Out:
#    data1 key  data2
# 0      0   b      1
# 1      1   b      1
# 2      6   b      1
# 3      2   a      0
# 4      4   a      0
# 5      5   a      0

# %%
# 指定连接的关键字列名,默认使用同名的列
pd.merge(df1, df2, on='key')
# Out:
#    data1 key  data2
# 0      0   b      1
# 1      1   b      1
# 2      6   b      1
# 3      2   a      0
# 4      4   a      0
# 5      5   a      0

# %%
# 使用left_on与right_on分别指定连接左右关键字列名
df3 = pd.DataFrame({'lkey': ['b', 'b', 'a', 'c', 'a', 'a', 'b'],
                    'data1': range(7)})
df4 = pd.DataFrame({'rkey': ['a', 'b', 'd'],
                    'data2': range(3)})
pd.merge(df3, df4, left_on='lkey', right_on='rkey')
# Out:
#    data1 lkey  data2 rkey
# 0      0    b      1    b
# 1      1    b      1    b
# 2      6    b      1    b
# 3      2    a      0    a
# 4      4    a      0    a
# 5      5    a      0    a

# %%
# 通过how指定连接的类型，如inner、left、right、outer，默认为inner
pd.merge(df1, df2, how='outer')
# Out:
#    data1 key  data2
# 0    0.0   b    1.0
# 1    1.0   b    1.0
# 2    6.0   b    1.0
# 3    2.0   a    0.0
# 4    4.0   a    0.0
# 5    5.0   a    0.0
# 6    3.0   c    NaN
# 7    NaN   d    2.0

# %%
df1 = pd.DataFrame({'key': ['b', 'b', 'a', 'c', 'a', 'b'],
                    'data1': range(6)})
df2 = pd.DataFrame({'key': ['a', 'b', 'a', 'b', 'd'],
                    'data2': range(5)})
pd.merge(df1, df2, on='key', how='left')
# Out:
#     data1 key  data2
# 0       0   b    1.0
# 1       0   b    3.0
# 2       1   b    1.0
# 3       1   b    3.0
# 4       2   a    0.0
# 5       2   a    2.0
# 6       3   c    NaN
# 7       4   a    0.0
# 8       4   a    2.0
# 9       5   b    1.0
# 10      5   b    3.0

# %%
# 通过suffixes可以指定重复列的列名后缀
left = pd.DataFrame({'key1': ['foo', 'foo', 'bar'],
                     'key2': ['one', 'two', 'one'],
                     'lval': [1, 2, 3]})
right = pd.DataFrame({'key1': ['foo', 'foo', 'bar', 'bar'],
                      'key2': ['one', 'one', 'one', 'two'],
                      'rval': [4, 5, 6, 7]})
pd.merge(left, right, on='key1', suffixes=('_left', '_right'))
# Out:
#   key1 key2_left  lval key2_right  rval
# 0  foo       one     1        one     4
# 1  foo       one     1        one     5
# 2  foo       two     2        one     4
# 3  foo       two     2        one     5
# 4  bar       one     3        one     6
# 5  bar       one     3        two     7

# %% [markdown]
# ## 基于index的连接
#
# 通过`left_index=True`或`right_index=Ture`可以指定将`DataFrame`的`index`列的值作为连接的关键字列。

# %%
left1 = pd.DataFrame({'key': ['a', 'b', 'a', 'a', 'b', 'c'], 'value': range(6)})
right1 = pd.DataFrame({'group_val': [3.5, 7]}, index=['a', 'b'])
pd.merge(left1, right1, left_on='key', right_index=True)
# Out:
#   key  value  group_val
# 0   a      0        3.5
# 2   a      2        3.5
# 3   a      3        3.5
# 1   b      1        7.0
# 4   b      4        7.0

# %%
pd.merge(left1, right1, left_on='key', right_index=True, how='outer')
# Out:
#   key  value  group_val
# 0   a      0        3.5
# 2   a      2        3.5
# 3   a      3        3.5
# 1   b      1        7.0
# 4   b      4        7.0
# 5   c      5        NaN

# %% [markdown]
# 基于`index`列的值进行连接操作对于分层索引仍然有效。

# %%
lefth = pd.DataFrame({'key1': ['Ohio', 'Ohio', 'Ohio','Nevada', 'Nevada'],
                      'key2': [2000, 2001, 2002, 2001, 2002],
                      'data': np.arange(5.)})
lefth
# Out:
#    data    key1  key2
# 0   0.0    Ohio  2000
# 1   1.0    Ohio  2001
# 2   2.0    Ohio  2002
# 3   3.0  Nevada  2001
# 4   4.0  Nevada  2002

# %%
righth = pd.DataFrame(np.arange(12).reshape((6, 2)),
                      index=[['Nevada', 'Nevada', 'Ohio', 'Ohio', 'Ohio', 'Ohio'],
                             [2001, 2000, 2000, 2000, 2001, 2002]],
                      columns=['event1', 'event2'])
righth
# Out:
#              event1  event2
# Nevada 2001       0       1
#        2000       2       3
# Ohio   2000       4       5
#        2000       6       7
#        2001       8       9
#        2002      10      11

# %%
pd.merge(lefth, righth, left_on=['key1', 'key2'], right_index=True)
# Out:
#    data    key1  key2  event1  event2
# 0   0.0    Ohio  2000       4       5
# 0   0.0    Ohio  2000       6       7
# 1   1.0    Ohio  2001       8       9
# 2   2.0    Ohio  2002      10      11
# 3   3.0  Nevada  2001       0       1

# %% [markdown]
# `join()`函数就是特殊的基于`index`的`merge()`方法。

# %%
left2 = pd.DataFrame([[1., 2.], [3., 4.], [5., 6.]],
                     index=['a', 'c', 'e'],
                     columns=['Ohio', 'Nevada'])
right2 = pd.DataFrame([[7., 8.], [9., 10.], [11., 12.], [13, 14]],
                      index=['b', 'c', 'd', 'e'],
                      columns=['Missouri', 'Alabama'])
pd.merge(left2, right2, how='outer', left_index=True, right_index=True)
# Out:
#    Ohio  Nevada  Missouri  Alabama
# a   1.0     2.0       NaN      NaN
# b   NaN     NaN       7.0      8.0
# c   3.0     4.0       9.0     10.0
# d   NaN     NaN      11.0     12.0
# e   5.0     6.0      13.0     14.0

# %% [markdown]
# 等价于

# %%
left2.join(right2, how='outer')
# Out:
#    Ohio  Nevada  Missouri  Alabama
# a   1.0     2.0       NaN      NaN
# b   NaN     NaN       7.0      8.0
# c   3.0     4.0       9.0     10.0
# d   NaN     NaN      11.0     12.0
# e   5.0     6.0      13.0     14.0

# %% [markdown]
# 可以将一个包含若干`DataFrame`的列表作为参数传入`join()`方法中。

# %%
another = pd.DataFrame([[7., 8.], [9., 10.], [11., 12.], [16., 17.]],
                       index=['a', 'c', 'e', 'f'],
                       columns=['New York', 'Oregon'])
another
# Out:
#    New York  Oregon
# a       7.0     8.0
# c       9.0    10.0
# e      11.0    12.0
# f      16.0    17.0

# %%
left2.join([right2, another])
# Out:
#    Ohio  Nevada  Missouri  Alabama  New York  Oregon
# a   1.0     2.0       NaN      NaN       7.0     8.0
# c   3.0     4.0       9.0     10.0       9.0    10.0
# e   5.0     6.0      13.0     14.0      11.0    12.0

# %%
left2.join([right2, another], how='outer')
# Out:
#    Ohio  Nevada  Missouri  Alabama  New York  Oregon
# a   1.0     2.0       NaN      NaN       7.0     8.0
# b   NaN     NaN       7.0      8.0       NaN     NaN
# c   3.0     4.0       9.0     10.0       9.0    10.0
# d   NaN     NaN      11.0     12.0       NaN     NaN
# e   5.0     6.0      13.0     14.0      11.0    12.0
# f   NaN     NaN       NaN      NaN      16.0    17.0

# %% [markdown]
# ## 沿坐标轴拼接
#
# `pd.concat()`可以将一个或多个`Series`或`DataFrame`沿着指定的坐标轴纵向或横向拼接在一起。
#
# 对于多个`Series`对象，默认采用纵向拼接方式。

# %%
s1 = pd.Series([0, 1], index=['a', 'b'])
s2 = pd.Series([2, 3, 4], index=['c', 'd', 'e'])
s3 = pd.Series([5, 6], index=['f', 'g'])

pd.concat([s1, s2, s3])
# Out:
# a    0
# b    1
# c    2
# d    3
# e    4
# f    5
# g    6
# dtype: int64

# %% [markdown]
# 指定`axis=1`后将多个`Series`横向拼接为一个新的`DataFrame`对象。

# %%
pd.concat([s1, s2, s3], axis=1)
# Out:
#      0    1    2
# a  0.0  NaN  NaN
# b  1.0  NaN  NaN
# c  NaN  2.0  NaN
# d  NaN  3.0  NaN
# e  NaN  4.0  NaN
# f  NaN  NaN  5.0
# g  NaN  NaN  6.0

# %% [markdown]
# 通过`join`参数，能够对行或列进行连接操作后拼接。

# %%
s4 = pd.concat([s1, s3])
s4
# Out:
# a    0
# b    1
# f    5
# g    6
# dtype: int64

# %%
s1
# Out:
# a    0
# b    1
# dtype: int64

# %%
pd.concat([s1, s4], axis=1, join='inner')
# Out:
#    0  1
# a  0  0
# b  1  1
