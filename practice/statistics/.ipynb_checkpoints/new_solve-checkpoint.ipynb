# %%
import numpy as np
import pandas as pd

filename = '330.xlsx'
df = pd.read_excel(filename, sheet_name=1)
# df[['MEN', 'TASK', 'ACCESS', 'PREP']] = df[['MEN', 'TASK', 'ACCESS', 'PREP']].fillna(0)
df[['MEN', 'TASK', 'ACCESS', 'PREP']] = df[['MEN', 'TASK', 'ACCESS', 'PREP']].apply(pd.to_numeric, errors='coerce')

# %%
df[['MEN', 'TASK', 'ACCESS', 'PREP']] = df[['MEN', 'TASK', 'ACCESS', 'PREP']].fillna(0)
df
# Out:
#        TASKNUMBER  ZONE                                      DESCRIPTION  \
# 0     200001-01-1   522                   LIGHTNING/HIRF PROTECTION-WING
# 1     200001-01-1   622                   LIGHTNING/HIRF PROTECTION-WING
# 2     200001-03-1   633                   LIGHTNING/HIRF PROTECTION-WING
# 3     200001-04-1   523                   LIGHTNING/HIRF PROTECTION-WING
# 4     200001-04-1   623                   LIGHTNING/HIRF PROTECTION-WING
# 5     200001-05-1   533                   LIGHTNING/HIRF PROTECTION-WING
# 6     200001-05-1   574                   LIGHTNING/HIRF PROTECTION-WING
# 7     200001-05-1   633                   LIGHTNING/HIRF PROTECTION-WING
# 8     200001-05-1   674                   LIGHTNING/HIRF PROTECTION-WING
# 9     200001-06-1   531                   LIGHTNING/HIRF PROTECTION-WING
# 10    200001-06-1   631                   LIGHTNING/HIRF PROTECTION-WING
# 11    200001-08-1   571                   LIGHTNING/HIRF PROTECTION-WING
# 12    200001-08-1   671                   LIGHTNING/HIRF PROTECTION-WING
# 13    200001-09-1   531                   LIGHTNING/HIRF PROTECTION-WING
# 14    200001-09-1   631                   LIGHTNING/HIRF PROTECTION-WING
# 15    200001-14-1   147                  LIGHTNING/HIRF PROTECTION- WING
# 16    200001-14-1   148                  LIGHTNING/HIRF PROTECTION- WING
# 17    200001-14-1   191                  LIGHTNING/HIRF PROTECTION- WING
# 18    200001-14-1   192                  LIGHTNING/HIRF PROTECTION- WING
# 19    200002-01-1   310  LIGHTNING/HIRF PROTECTION-REAR FUSELAGE SECTION
# 20    200002-02-1   313  LIGHTNING/HIRF PROTECTION-REAR FUSELAGE SECTION
# 21    200002-02-1   314  LIGHTNING/HIRF PROTECTION-REAR FUSELAGE SECTION
# 22    200002-03-1   311              LIGHTNING/HIRF PROTECTION-TAIL CONE
# 23    200002-03-1   312              LIGHTNING/HIRF PROTECTION-TAIL CONE
# 24    200003-01-1   193          LIGHTNING/HIRF PROTECTION-BELLY FAIRING
# 25    200003-03-1   191          LIGHTNING/HIRF PROTECTION-BELLY FAIRING
# 26    200003-03-1   192          LIGHTNING/HIRF PROTECTION-BELLY FAIRING
# 27    200003-03-1   198          LIGHTNING/HIRF PROTECTION-BELLY FAIRING
# 28    200004-01-1   454           LIGHTNING/HIRF PROTECTION-ENGINE PYLON
# 29    200004-01-1   464           LIGHTNING/HIRF PROTECTION-ENGINE PYLON
# ...           ...   ...                                              ...
# 6987  ZL-811-01-1   811                FORWARD AVIONICS COMPARTMENT DOOR
# 6988  ZL-821-01-1   821                   FORWARD CARGO COMPARTMENT DOOR
# 6989  ZL-821-02-1   821                   FORWARD CARGO COMPARTMENT DOOR
# 6990  ZL-821-03-1   821                   FORWARD CARGO COMPARTMENT DOOR
# 6991  ZL-822-01-1   822                       AFT CARGO COMPARTMENT DOOR
# 6992  ZL-822-02-1   822                       AFT CARGO COMPARTMENT DOOR
# 6993  ZL-822-03-1   822                       AFT CARGO COMPARTMENT DOOR
# 6994  ZL-823-01-1   823                      BULK CARGO COMPARTMENT DOOR
# 6995  ZL-823-02-1   823                      BULK CARGO COMPARTMENT DOOR
# 6996  ZL-831-01-1   831                     FORWARD PASSENGER/CREW DOORS
# 6997  ZL-831-01-1   841                     FORWARD PASSENGER/CREW DOORS
# 6998  ZL-831-02-1   831                     FORWARD PASSENGER/CREW DOORS
# 6999  ZL-831-02-1   841                     FORWARD PASSENGER/CREW DOORS
# 7000  ZL-832-01-1   832                         MID PASSENGER/CREW DOORS
# 7001  ZL-832-01-1   842                         MID PASSENGER/CREW DOORS
# 7002  ZL-832-02-1   832                         MID PASSENGER/CREW DOORS
# 7003  ZL-832-02-1   842                         MID PASSENGER/CREW DOORS
# 7004  ZL-833-01-1   833                         AFT PASSENGER/CREW DOORS
# 7005  ZL-833-01-1   843                         AFT PASSENGER/CREW DOORS
# 7006  ZL-833-02-1   833                         AFT PASSENGER/CREW DOORS
# 7007  ZL-833-02-1   843                         AFT PASSENGER/CREW DOORS
# 7008  ZL-834-01-1   834                                  EMERGENCY EXITS
# 7009  ZL-834-01-1   844                                  EMERGENCY EXITS
# 7010  ZL-834-02-1   834                                  EMERGENCY EXITS
# 7011  ZL-834-02-1   844                                  EMERGENCY EXITS
# 7012  ZL-834-03-1   834                                  EMERGENCY EXITS
# 7013  ZL-834-03-1   844                                  EMERGENCY EXITS
# 7014  ZL-835-01-1   835                 MAIN DECK CARGO COMPARTMENT DOOR
# 7015  ZL-835-02-1   835                 MAIN DECK CARGO COMPARTMENT DOOR
# 7016  ZL-835-03-1   835                 MAIN DECK CARGO COMPARTMENT DOOR
#
#      SKILL CODE TASK CODE SAMPLE\nTHRESHOLD SAMPLE\nINTERVAL 100%\nTHRESHOLD  \
# 0            EL       CHK               NaN              NaN             NaN
# 1            EL       CHK               NaN              NaN             NaN
# 2            EL       CHK               NaN              NaN             NaN
# 3            EL       GVI               NaN              NaN             NaN
# 4            EL       GVI               NaN              NaN             NaN
# 5            EL       GVI               NaN              NaN             NaN
# 6            EL       GVI               NaN              NaN             NaN
# 7            EL       GVI               NaN              NaN             NaN
# 8            EL       GVI               NaN              NaN             NaN
# 9            EL       DET               NaN              NaN             NaN
# 10           EL       DET               NaN              NaN             NaN
# 11           EL       GVI               NaN              NaN             NaN
# 12           EL       GVI               NaN              NaN             NaN
# 13           EL       DET               NaN              NaN             NaN
# 14           EL       DET               NaN              NaN             NaN
# 15           EL       FNC               NaN              NaN             NaN
# 16           EL       FNC               NaN              NaN             NaN
# 17           EL       FNC               NaN              NaN             NaN
# 18           EL       FNC               NaN              NaN             NaN
# 19           EL       CHK               NaN              NaN             NaN
# 20           EL       FNC               NaN              NaN             NaN
# 21           EL       FNC               NaN              NaN             NaN
# 22           EL       FNC               NaN              NaN             NaN
# 23           EL       FNC               NaN              NaN             NaN
# 24           EL       GVI               NaN              NaN             NaN
# 25           EL       FNC               NaN              NaN             NaN
# 26           EL       FNC               NaN              NaN             NaN
# 27           EL       FNC               NaN              NaN             NaN
# 28           EL       GVI               NaN              NaN             NaN
# 29           EL       GVI               NaN              NaN             NaN
# ...         ...       ...               ...              ...             ...
# 6987         AF       GVI               NaN              NaN             NaN
# 6988         AF       GVI               NaN              NaN             NaN
# 6989         AF       GVI               NaN              NaN             NaN
# 6990         AF       GVI               NaN              NaN             NaN
# 6991         AF       GVI               NaN              NaN             NaN
# 6992         AF       GVI               NaN              NaN             NaN
# 6993         AF       GVI               NaN              NaN             NaN
# 6994         AF       GVI               NaN              NaN             NaN
# 6995         AF       GVI               NaN              NaN             NaN
# 6996         AF       GVI               NaN              NaN             NaN
# 6997         AF       GVI               NaN              NaN             NaN
# 6998         AF       GVI               NaN              NaN             NaN
# 6999         AF       GVI               NaN              NaN             NaN
# 7000         AF       GVI               NaN              NaN             NaN
# 7001         AF       GVI               NaN              NaN             NaN
# 7002         AF       GVI               NaN              NaN             NaN
# 7003         AF       GVI               NaN              NaN             NaN
# 7004         AF       GVI               NaN              NaN             NaN
# 7005         AF       GVI               NaN              NaN             NaN
# 7006         AF       GVI               NaN              NaN             NaN
# 7007         AF       GVI               NaN              NaN             NaN
# 7008         AF       GVI               NaN              NaN             NaN
# 7009         AF       GVI               NaN              NaN             NaN
# 7010         AF       GVI               NaN              NaN             NaN
# 7011         AF       GVI               NaN              NaN             NaN
# 7012         AF       GVI               NaN              NaN             NaN
# 7013         AF       GVI               NaN              NaN             NaN
# 7014         AF       GVI               NaN              NaN             NaN
# 7015         AF       GVI               NaN              NaN             NaN
# 7016         AF       GVI               NaN              NaN             NaN
#
#      100%\nINTERVAL SAMPLE\nTHRESHOLD.1  \
# 0               4 C                 NaN
# 1               4 C                 NaN
# 2             36 MO                 NaN
# 3             24 MO                 NaN
# 4             24 MO                 NaN
# 5             36 MO                 NaN
# 6             36 MO                 NaN
# 7             36 MO                 NaN
# 8             36 MO                 NaN
# 9             36 MO                 NaN
# 10            36 MO                 NaN
# 11            36 MO                 NaN
# 12            36 MO                 NaN
# 13            36 MO                 NaN
# 14            36 MO                 NaN
# 15              4 C                 NaN
# 16              4 C                 NaN
# 17              4 C                 NaN
# 18              4 C                 NaN
# 19            42 MO                 NaN
# 20            72 MO                 NaN
# 21            72 MO                 NaN
# 22            72 MO                 NaN
# 23            72 MO                 NaN
# 24            42 MO                 NaN
# 25              4 C                 NaN
# 26              4 C                 NaN
# 27              4 C                 NaN
# 28            42 MO                 NaN
# 29            42 MO                 NaN
# ...             ...                 ...
# 6987          24 MO                 NaN
# 6988            1 A                 NaN
# 6989            4 C                 NaN
# 6990            8 C                 NaN
# 6991            1 A                 NaN
# 6992            4 C                 NaN
# 6993            8 C                 NaN
# 6994            1 A                 NaN
# 6995            4 C                 NaN
# 6996          24 MO                 NaN
# 6997          24 MO                 NaN
# 6998            8 C                 NaN
# 6999            8 C                 NaN
# 7000          24 MO                 NaN
# 7001          24 MO                 NaN
# 7002            8 C                 NaN
# 7003            8 C                 NaN
# 7004          24 MO                 NaN
# 7005          24 MO                 NaN
# 7006            8 C                 NaN
# 7007            8 C                 NaN
# 7008          24 MO                 NaN
# 7009          24 MO                 NaN
# 7010            8 C                 NaN
# 7011            8 C                 NaN
# 7012            8 C                 NaN
# 7013            8 C                 NaN
# 7014            1 A                 NaN
# 7015            4 C                 NaN
# 7016            8 C                 NaN
#
#                             ...                        100%\nTHRESHOLD.2  \
# 0                           ...                                      NaN
# 1                           ...                                      NaN
# 2                           ...                                      NaN
# 3                           ...                                      NaN
# 4                           ...                                      NaN
# 5                           ...                                      NaN
# 6                           ...                                      NaN
# 7                           ...                                      NaN
# 8                           ...                                      NaN
# 9                           ...                                      NaN
# 10                          ...                                      NaN
# 11                          ...                                      NaN
# 12                          ...                                      NaN
# 13                          ...                                      NaN
# 14                          ...                                      NaN
# 15                          ...                                      NaN
# 16                          ...                                      NaN
# 17                          ...                                      NaN
# 18                          ...                                      NaN
# 19                          ...                                      NaN
# 20                          ...                                      NaN
# 21                          ...                                      NaN
# 22                          ...                                      NaN
# 23                          ...                                      NaN
# 24                          ...                                      NaN
# 25                          ...                                      NaN
# 26                          ...                                      NaN
# 27                          ...                                      NaN
# 28                          ...                                      NaN
# 29                          ...                                      NaN
# ...                         ...                                      ...
# 6987                        ...                                      NaN
# 6988                        ...                                      NaN
# 6989                        ...                                      NaN
# 6990                        ...                                      NaN
# 6991                        ...                                      NaN
# 6992                        ...                                      NaN
# 6993                        ...                                      NaN
# 6994                        ...                                      NaN
# 6995                        ...                                      NaN
# 6996                        ...                                      NaN
# 6997                        ...                                      NaN
# 6998                        ...                                      NaN
# 6999                        ...                                      NaN
# 7000                        ...                                      NaN
# 7001                        ...                                      NaN
# 7002                        ...                                      NaN
# 7003                        ...                                      NaN
# 7004                        ...                                      NaN
# 7005                        ...                                      NaN
# 7006                        ...                                      NaN
# 7007                        ...                                      NaN
# 7008                        ...                                      NaN
# 7009                        ...                                      NaN
# 7010                        ...                                      NaN
# 7011                        ...                                      NaN
# 7012                        ...                                      NaN
# 7013                        ...                                      NaN
# 7014                        ...                                      NaN
# 7015                        ...                                      NaN
# 7016                        ...                                      NaN
#
#      100%\nINTERVAL.2      SOURCE  TCI  TPS MEN  TASK ACCESS  PREP  \
# 0                 NaN  MRB L/HIRF  NaN  NaN   1  0.10   0.80  0.00
# 1                 NaN  MRB L/HIRF  NaN  NaN   1  0.10   0.80  0.00
# 2                 NaN  MRB L/HIRF  NaN  NaN   1  0.05   0.00  0.00
# 3                 NaN  MRB L/HIRF  NaN  NaN   1  0.40   1.90  0.00
# 4                 NaN  MRB L/HIRF  NaN  NaN   1  0.40   1.90  0.00
# 5                 NaN  MRB L/HIRF  NaN  NaN   1  0.15   1.00  0.00
# 6                 NaN  MRB L/HIRF  NaN  NaN   1  0.15   0.00  0.00
# 7                 NaN  MRB L/HIRF  NaN  NaN   1  0.15   1.00  0.00
# 8                 NaN  MRB L/HIRF  NaN  NaN   1  0.15   0.00  0.00
# 9                 NaN  MRB L/HIRF  NaN  NaN   1  0.40   1.15  4.02
# 10                NaN  MRB L/HIRF  NaN  NaN   1  0.40   1.15  4.02
# 11                NaN  MRB L/HIRF  NaN  NaN   1  0.30   0.00  0.00
# 12                NaN  MRB L/HIRF  NaN  NaN   1  0.30   0.00  0.00
# 13                NaN  MRB L/HIRF  NaN  NaN   1  0.40   1.15  4.02
# 14                NaN  MRB L/HIRF  NaN  NaN   1  0.40   1.15  4.02
# 15                NaN  MRB L/HIRF  NaN  NaN   1  0.50   0.00  0.00
# 16                NaN  MRB L/HIRF  NaN  NaN   1  0.50   0.00  0.00
# 17                NaN  MRB L/HIRF  NaN  NaN   1  0.50   0.40  1.00
# 18                NaN  MRB L/HIRF  NaN  NaN   1  0.50   0.40  1.00
# 19                NaN  MRB L/HIRF  NaN  NaN   1  0.05   0.01  0.00
# 20                NaN  MRB L/HIRF  NaN  NaN   1  0.19   0.02  0.00
# 21                NaN  MRB L/HIRF  NaN  NaN   1  0.19   0.00  0.00
# 22                NaN  MRB L/HIRF  NaN  NaN   1  0.10   0.00  0.00
# 23                NaN  MRB L/HIRF  NaN  NaN   1  0.10   0.01  0.00
# 24                NaN  MRB L/HIRF  NaN  NaN   1  0.40   1.60  0.00
# 25                NaN  MRB L/HIRF  NaN  NaN   1  0.15   2.50  0.00
# 26                NaN  MRB L/HIRF  NaN  NaN   1  0.15   2.25  0.00
# 27                NaN  MRB L/HIRF  NaN  NaN   1  0.15   1.60  0.00
# 28                NaN  MRB L/HIRF  NaN  NaN   1  0.25   0.30  0.00
# 29                NaN  MRB L/HIRF  NaN  NaN   1  0.25   0.30  0.00
# ...               ...         ...  ...  ...  ..   ...    ...   ...
# 6987              NaN         MRB  NaN  NaN   1  0.15   0.07  0.00
# 6988              NaN         MRB  NaN  NaN   1  0.20   0.10  0.00
# 6989              NaN         MRB  NaN  NaN   1  0.75   1.16  0.00
# 6990              NaN         MRB  NaN  NaN   1  1.00   0.85  0.00
# 6991              NaN         MRB  NaN  NaN   1  0.20   0.10  0.00
# 6992              NaN         MRB  NaN  NaN   1  0.75   1.17  0.00
# 6993              NaN         MRB  NaN  NaN   1  1.00   0.85  0.00
# 6994              NaN         MRB  NaN  NaN   1  0.20   0.05  0.00
# 6995              NaN         MRB  NaN  NaN   1  0.50   0.05  0.00
# 6996              NaN         MRB  NaN  NaN   1  0.20   0.02  0.00
# 6997              NaN         MRB  NaN  NaN   1  0.20   0.02  0.00
# 6998              NaN         MRB  NaN  NaN   1  0.50   0.66  0.00
# 6999              NaN         MRB  NaN  NaN   1  0.50   0.66  0.00
# 7000              NaN         MRB  NaN  NaN   1  0.20   0.02  0.00
# 7001              NaN         MRB  NaN  NaN   1  0.20   0.02  0.00
# 7002              NaN         MRB  NaN  NaN   1  0.50   0.66  0.00
# 7003              NaN         MRB  NaN  NaN   1  0.50   0.66  0.00
# 7004              NaN         MRB  NaN  NaN   1  0.20   0.02  0.00
# 7005              NaN         MRB  NaN  NaN   1  0.20   0.02  0.00
# 7006              NaN         MRB  NaN  NaN   1  0.50   0.66  0.00
# 7007              NaN         MRB  NaN  NaN   1  0.50   0.66  0.00
# 7008              NaN         MRB  NaN  NaN   1  0.20   0.02  0.00
# 7009              NaN         MRB  NaN  NaN   1  0.20   0.02  0.00
# 7010              NaN         MRB  NaN  NaN   1  0.50   0.66  0.00
# 7011              NaN         MRB  NaN  NaN   1  0.50   0.66  0.00
# 7012              NaN         MRB  NaN  NaN   1  0.50   0.48  0.00
# 7013              NaN         MRB  NaN  NaN   1  0.50   0.48  0.00
# 7014              NaN         MRB  NaN  NaN   1  0.30   0.02  0.00
# 7015              NaN         MRB  NaN  NaN   1  0.75   0.02  0.00
# 7016              NaN         MRB  NaN  NaN   1  1.00   0.02  0.00
#
#                                          APPLICABILITY
# 0                                                  ALL
# 1                                                  ALL
# 2                                                  ALL
# 3                                                  ALL
# 4                                                  ALL
# 5                                                  ALL
# 6                                                  ALL
# 7                                                  ALL
# 8                                                  ALL
# 9                                           PRE  43165
# 10                                          PRE  43165
# 11                                                 ALL
# 12                                                 ALL
# 13                                          POST 43165
# 14                                          POST 43165
# 15                               PRE  53665\n(92-3062)
# 16                               PRE  53665\n(92-3062)
# 17                               PRE  53665\n(92-3062)
# 18                               PRE  53665\n(92-3062)
# 19                                                 ALL
# 20                                                 ALL
# 21                                                 ALL
# 22                                                 ALL
# 23                                                 ALL
# 24                                                 ALL
# 25                               PRE  53665\n(92-3062)
# 26                               PRE  53665\n(92-3062)
# 27                               PRE  53665\n(92-3062)
# 28                                                 ALL
# 29                                                 ALL
# ...                                                ...
# 6987                                               ALL
# 6988                                               ALL
# 6989                                               ALL
# 6990                                               ALL
# 6991                                               ALL
# 6992                                               ALL
# 6993                                               ALL
# 6994                                               ALL
# 6995                                               ALL
# 6996                                               ALL
# 6997                                               ALL
# 6998                                               ALL
# 6999                                               ALL
# 7000                            A330-200\nOR\nA330-300
# 7001                            A330-200\nOR\nA330-300
# 7002                            A330-200\nOR\nA330-300
# 7003                            A330-200\nOR\nA330-300
# 7004                            A330-200\nOR\nA330-300
# 7005                            A330-200\nOR\nA330-300
# 7006                            A330-200\nOR\nA330-300
# 7007                            A330-200\nOR\nA330-300
# 7008                            A330-200\nOR\nA330-300
# 7009                            A330-200\nOR\nA330-300
# 7010  A330-200\nDOOR TYPE A\nOR\nA330-300\nDOOR TYPE A
# 7011  A330-200\nDOOR TYPE A\nOR\nA330-300\nDOOR TYPE A
# 7012  A330-200\nDOOR TYPE I\nOR\nA330-300\nDOOR TYPE I
# 7013  A330-200\nDOOR TYPE I\nOR\nA330-300\nDOOR TYPE I
# 7014                                         A330-200F
# 7015                                         A330-200F
# 7016                                         A330-200F
#
# [7017 rows x 25 columns]

# %%
# df['MEN'].apply(lambda x: x if type(eval(x)) == float else 0 )
# def judge(x):
#     try:
#         float(x)
#     except:
#         return False
#     return True

# df['MEN'].apply(lambda x: x if judge(x) else 0)
# df['TASK'].apply(lambda x: x if judge(x) else 0)
# df['ACCESS'].apply(lambda x: x if judge(x) else 0)
# df['PREP'].apply(lambda x: x if judge(x) else 0)
# df
# Out:
#        TASKNUMBER  ZONE                                      DESCRIPTION  \
# 0     200001-01-1   522                   LIGHTNING/HIRF PROTECTION-WING
# 1     200001-01-1   622                   LIGHTNING/HIRF PROTECTION-WING
# 2     200001-03-1   633                   LIGHTNING/HIRF PROTECTION-WING
# 3     200001-04-1   523                   LIGHTNING/HIRF PROTECTION-WING
# 4     200001-04-1   623                   LIGHTNING/HIRF PROTECTION-WING
# 5     200001-05-1   533                   LIGHTNING/HIRF PROTECTION-WING
# 6     200001-05-1   574                   LIGHTNING/HIRF PROTECTION-WING
# 7     200001-05-1   633                   LIGHTNING/HIRF PROTECTION-WING
# 8     200001-05-1   674                   LIGHTNING/HIRF PROTECTION-WING
# 9     200001-06-1   531                   LIGHTNING/HIRF PROTECTION-WING
# 10    200001-06-1   631                   LIGHTNING/HIRF PROTECTION-WING
# 11    200001-08-1   571                   LIGHTNING/HIRF PROTECTION-WING
# 12    200001-08-1   671                   LIGHTNING/HIRF PROTECTION-WING
# 13    200001-09-1   531                   LIGHTNING/HIRF PROTECTION-WING
# 14    200001-09-1   631                   LIGHTNING/HIRF PROTECTION-WING
# 15    200001-14-1   147                  LIGHTNING/HIRF PROTECTION- WING
# 16    200001-14-1   148                  LIGHTNING/HIRF PROTECTION- WING
# 17    200001-14-1   191                  LIGHTNING/HIRF PROTECTION- WING
# 18    200001-14-1   192                  LIGHTNING/HIRF PROTECTION- WING
# 19    200002-01-1   310  LIGHTNING/HIRF PROTECTION-REAR FUSELAGE SECTION
# 20    200002-02-1   313  LIGHTNING/HIRF PROTECTION-REAR FUSELAGE SECTION
# 21    200002-02-1   314  LIGHTNING/HIRF PROTECTION-REAR FUSELAGE SECTION
# 22    200002-03-1   311              LIGHTNING/HIRF PROTECTION-TAIL CONE
# 23    200002-03-1   312              LIGHTNING/HIRF PROTECTION-TAIL CONE
# 24    200003-01-1   193          LIGHTNING/HIRF PROTECTION-BELLY FAIRING
# 25    200003-03-1   191          LIGHTNING/HIRF PROTECTION-BELLY FAIRING
# 26    200003-03-1   192          LIGHTNING/HIRF PROTECTION-BELLY FAIRING
# 27    200003-03-1   198          LIGHTNING/HIRF PROTECTION-BELLY FAIRING
# 28    200004-01-1   454           LIGHTNING/HIRF PROTECTION-ENGINE PYLON
# 29    200004-01-1   464           LIGHTNING/HIRF PROTECTION-ENGINE PYLON
# ...           ...   ...                                              ...
# 6987  ZL-811-01-1   811                FORWARD AVIONICS COMPARTMENT DOOR
# 6988  ZL-821-01-1   821                   FORWARD CARGO COMPARTMENT DOOR
# 6989  ZL-821-02-1   821                   FORWARD CARGO COMPARTMENT DOOR
# 6990  ZL-821-03-1   821                   FORWARD CARGO COMPARTMENT DOOR
# 6991  ZL-822-01-1   822                       AFT CARGO COMPARTMENT DOOR
# 6992  ZL-822-02-1   822                       AFT CARGO COMPARTMENT DOOR
# 6993  ZL-822-03-1   822                       AFT CARGO COMPARTMENT DOOR
# 6994  ZL-823-01-1   823                      BULK CARGO COMPARTMENT DOOR
# 6995  ZL-823-02-1   823                      BULK CARGO COMPARTMENT DOOR
# 6996  ZL-831-01-1   831                     FORWARD PASSENGER/CREW DOORS
# 6997  ZL-831-01-1   841                     FORWARD PASSENGER/CREW DOORS
# 6998  ZL-831-02-1   831                     FORWARD PASSENGER/CREW DOORS
# 6999  ZL-831-02-1   841                     FORWARD PASSENGER/CREW DOORS
# 7000  ZL-832-01-1   832                         MID PASSENGER/CREW DOORS
# 7001  ZL-832-01-1   842                         MID PASSENGER/CREW DOORS
# 7002  ZL-832-02-1   832                         MID PASSENGER/CREW DOORS
# 7003  ZL-832-02-1   842                         MID PASSENGER/CREW DOORS
# 7004  ZL-833-01-1   833                         AFT PASSENGER/CREW DOORS
# 7005  ZL-833-01-1   843                         AFT PASSENGER/CREW DOORS
# 7006  ZL-833-02-1   833                         AFT PASSENGER/CREW DOORS
# 7007  ZL-833-02-1   843                         AFT PASSENGER/CREW DOORS
# 7008  ZL-834-01-1   834                                  EMERGENCY EXITS
# 7009  ZL-834-01-1   844                                  EMERGENCY EXITS
# 7010  ZL-834-02-1   834                                  EMERGENCY EXITS
# 7011  ZL-834-02-1   844                                  EMERGENCY EXITS
# 7012  ZL-834-03-1   834                                  EMERGENCY EXITS
# 7013  ZL-834-03-1   844                                  EMERGENCY EXITS
# 7014  ZL-835-01-1   835                 MAIN DECK CARGO COMPARTMENT DOOR
# 7015  ZL-835-02-1   835                 MAIN DECK CARGO COMPARTMENT DOOR
# 7016  ZL-835-03-1   835                 MAIN DECK CARGO COMPARTMENT DOOR
#
#      SKILL CODE TASK CODE SAMPLE\nTHRESHOLD SAMPLE\nINTERVAL 100%\nTHRESHOLD  \
# 0            EL       CHK               NaN              NaN             NaN
# 1            EL       CHK               NaN              NaN             NaN
# 2            EL       CHK               NaN              NaN             NaN
# 3            EL       GVI               NaN              NaN             NaN
# 4            EL       GVI               NaN              NaN             NaN
# 5            EL       GVI               NaN              NaN             NaN
# 6            EL       GVI               NaN              NaN             NaN
# 7            EL       GVI               NaN              NaN             NaN
# 8            EL       GVI               NaN              NaN             NaN
# 9            EL       DET               NaN              NaN             NaN
# 10           EL       DET               NaN              NaN             NaN
# 11           EL       GVI               NaN              NaN             NaN
# 12           EL       GVI               NaN              NaN             NaN
# 13           EL       DET               NaN              NaN             NaN
# 14           EL       DET               NaN              NaN             NaN
# 15           EL       FNC               NaN              NaN             NaN
# 16           EL       FNC               NaN              NaN             NaN
# 17           EL       FNC               NaN              NaN             NaN
# 18           EL       FNC               NaN              NaN             NaN
# 19           EL       CHK               NaN              NaN             NaN
# 20           EL       FNC               NaN              NaN             NaN
# 21           EL       FNC               NaN              NaN             NaN
# 22           EL       FNC               NaN              NaN             NaN
# 23           EL       FNC               NaN              NaN             NaN
# 24           EL       GVI               NaN              NaN             NaN
# 25           EL       FNC               NaN              NaN             NaN
# 26           EL       FNC               NaN              NaN             NaN
# 27           EL       FNC               NaN              NaN             NaN
# 28           EL       GVI               NaN              NaN             NaN
# 29           EL       GVI               NaN              NaN             NaN
# ...         ...       ...               ...              ...             ...
# 6987         AF       GVI               NaN              NaN             NaN
# 6988         AF       GVI               NaN              NaN             NaN
# 6989         AF       GVI               NaN              NaN             NaN
# 6990         AF       GVI               NaN              NaN             NaN
# 6991         AF       GVI               NaN              NaN             NaN
# 6992         AF       GVI               NaN              NaN             NaN
# 6993         AF       GVI               NaN              NaN             NaN
# 6994         AF       GVI               NaN              NaN             NaN
# 6995         AF       GVI               NaN              NaN             NaN
# 6996         AF       GVI               NaN              NaN             NaN
# 6997         AF       GVI               NaN              NaN             NaN
# 6998         AF       GVI               NaN              NaN             NaN
# 6999         AF       GVI               NaN              NaN             NaN
# 7000         AF       GVI               NaN              NaN             NaN
# 7001         AF       GVI               NaN              NaN             NaN
# 7002         AF       GVI               NaN              NaN             NaN
# 7003         AF       GVI               NaN              NaN             NaN
# 7004         AF       GVI               NaN              NaN             NaN
# 7005         AF       GVI               NaN              NaN             NaN
# 7006         AF       GVI               NaN              NaN             NaN
# 7007         AF       GVI               NaN              NaN             NaN
# 7008         AF       GVI               NaN              NaN             NaN
# 7009         AF       GVI               NaN              NaN             NaN
# 7010         AF       GVI               NaN              NaN             NaN
# 7011         AF       GVI               NaN              NaN             NaN
# 7012         AF       GVI               NaN              NaN             NaN
# 7013         AF       GVI               NaN              NaN             NaN
# 7014         AF       GVI               NaN              NaN             NaN
# 7015         AF       GVI               NaN              NaN             NaN
# 7016         AF       GVI               NaN              NaN             NaN
#
#      100%\nINTERVAL SAMPLE\nTHRESHOLD.1  \
# 0               4 C                 NaN
# 1               4 C                 NaN
# 2             36 MO                 NaN
# 3             24 MO                 NaN
# 4             24 MO                 NaN
# 5             36 MO                 NaN
# 6             36 MO                 NaN
# 7             36 MO                 NaN
# 8             36 MO                 NaN
# 9             36 MO                 NaN
# 10            36 MO                 NaN
# 11            36 MO                 NaN
# 12            36 MO                 NaN
# 13            36 MO                 NaN
# 14            36 MO                 NaN
# 15              4 C                 NaN
# 16              4 C                 NaN
# 17              4 C                 NaN
# 18              4 C                 NaN
# 19            42 MO                 NaN
# 20            72 MO                 NaN
# 21            72 MO                 NaN
# 22            72 MO                 NaN
# 23            72 MO                 NaN
# 24            42 MO                 NaN
# 25              4 C                 NaN
# 26              4 C                 NaN
# 27              4 C                 NaN
# 28            42 MO                 NaN
# 29            42 MO                 NaN
# ...             ...                 ...
# 6987          24 MO                 NaN
# 6988            1 A                 NaN
# 6989            4 C                 NaN
# 6990            8 C                 NaN
# 6991            1 A                 NaN
# 6992            4 C                 NaN
# 6993            8 C                 NaN
# 6994            1 A                 NaN
# 6995            4 C                 NaN
# 6996          24 MO                 NaN
# 6997          24 MO                 NaN
# 6998            8 C                 NaN
# 6999            8 C                 NaN
# 7000          24 MO                 NaN
# 7001          24 MO                 NaN
# 7002            8 C                 NaN
# 7003            8 C                 NaN
# 7004          24 MO                 NaN
# 7005          24 MO                 NaN
# 7006            8 C                 NaN
# 7007            8 C                 NaN
# 7008          24 MO                 NaN
# 7009          24 MO                 NaN
# 7010            8 C                 NaN
# 7011            8 C                 NaN
# 7012            8 C                 NaN
# 7013            8 C                 NaN
# 7014            1 A                 NaN
# 7015            4 C                 NaN
# 7016            8 C                 NaN
#
#                             ...                        100%\nTHRESHOLD.2  \
# 0                           ...                                      NaN
# 1                           ...                                      NaN
# 2                           ...                                      NaN
# 3                           ...                                      NaN
# 4                           ...                                      NaN
# 5                           ...                                      NaN
# 6                           ...                                      NaN
# 7                           ...                                      NaN
# 8                           ...                                      NaN
# 9                           ...                                      NaN
# 10                          ...                                      NaN
# 11                          ...                                      NaN
# 12                          ...                                      NaN
# 13                          ...                                      NaN
# 14                          ...                                      NaN
# 15                          ...                                      NaN
# 16                          ...                                      NaN
# 17                          ...                                      NaN
# 18                          ...                                      NaN
# 19                          ...                                      NaN
# 20                          ...                                      NaN
# 21                          ...                                      NaN
# 22                          ...                                      NaN
# 23                          ...                                      NaN
# 24                          ...                                      NaN
# 25                          ...                                      NaN
# 26                          ...                                      NaN
# 27                          ...                                      NaN
# 28                          ...                                      NaN
# 29                          ...                                      NaN
# ...                         ...                                      ...
# 6987                        ...                                      NaN
# 6988                        ...                                      NaN
# 6989                        ...                                      NaN
# 6990                        ...                                      NaN
# 6991                        ...                                      NaN
# 6992                        ...                                      NaN
# 6993                        ...                                      NaN
# 6994                        ...                                      NaN
# 6995                        ...                                      NaN
# 6996                        ...                                      NaN
# 6997                        ...                                      NaN
# 6998                        ...                                      NaN
# 6999                        ...                                      NaN
# 7000                        ...                                      NaN
# 7001                        ...                                      NaN
# 7002                        ...                                      NaN
# 7003                        ...                                      NaN
# 7004                        ...                                      NaN
# 7005                        ...                                      NaN
# 7006                        ...                                      NaN
# 7007                        ...                                      NaN
# 7008                        ...                                      NaN
# 7009                        ...                                      NaN
# 7010                        ...                                      NaN
# 7011                        ...                                      NaN
# 7012                        ...                                      NaN
# 7013                        ...                                      NaN
# 7014                        ...                                      NaN
# 7015                        ...                                      NaN
# 7016                        ...                                      NaN
#
#      100%\nINTERVAL.2      SOURCE  TCI  TPS MEN  TASK ACCESS  PREP  \
# 0                 NaN  MRB L/HIRF  NaN  NaN   1  0.10   0.80     0
# 1                 NaN  MRB L/HIRF  NaN  NaN   1  0.10   0.80     0
# 2                 NaN  MRB L/HIRF  NaN  NaN   1  0.05      0     0
# 3                 NaN  MRB L/HIRF  NaN  NaN   1  0.40   1.90     0
# 4                 NaN  MRB L/HIRF  NaN  NaN   1  0.40   1.90     0
# 5                 NaN  MRB L/HIRF  NaN  NaN   1  0.15   1.00     0
# 6                 NaN  MRB L/HIRF  NaN  NaN   1  0.15      0     0
# 7                 NaN  MRB L/HIRF  NaN  NaN   1  0.15   1.00     0
# 8                 NaN  MRB L/HIRF  NaN  NaN   1  0.15      0     0
# 9                 NaN  MRB L/HIRF  NaN  NaN   1  0.40   1.15  4.02
# 10                NaN  MRB L/HIRF  NaN  NaN   1  0.40   1.15  4.02
# 11                NaN  MRB L/HIRF  NaN  NaN   1  0.30      0     0
# 12                NaN  MRB L/HIRF  NaN  NaN   1  0.30      0     0
# 13                NaN  MRB L/HIRF  NaN  NaN   1  0.40   1.15  4.02
# 14                NaN  MRB L/HIRF  NaN  NaN   1  0.40   1.15  4.02
# 15                NaN  MRB L/HIRF  NaN  NaN   1  0.50      0     0
# 16                NaN  MRB L/HIRF  NaN  NaN   1  0.50      0     0
# 17                NaN  MRB L/HIRF  NaN  NaN   1  0.50   0.40  1.00
# 18                NaN  MRB L/HIRF  NaN  NaN   1  0.50   0.40  1.00
# 19                NaN  MRB L/HIRF  NaN  NaN   1  0.05   0.01     0
# 20                NaN  MRB L/HIRF  NaN  NaN   1  0.19   0.02     0
# 21                NaN  MRB L/HIRF  NaN  NaN   1  0.19      0     0
# 22                NaN  MRB L/HIRF  NaN  NaN   1  0.10      0     0
# 23                NaN  MRB L/HIRF  NaN  NaN   1  0.10   0.01     0
# 24                NaN  MRB L/HIRF  NaN  NaN   1  0.40   1.60     0
# 25                NaN  MRB L/HIRF  NaN  NaN   1  0.15   2.50     0
# 26                NaN  MRB L/HIRF  NaN  NaN   1  0.15   2.25     0
# 27                NaN  MRB L/HIRF  NaN  NaN   1  0.15   1.60     0
# 28                NaN  MRB L/HIRF  NaN  NaN   1  0.25   0.30     0
# 29                NaN  MRB L/HIRF  NaN  NaN   1  0.25   0.30     0
# ...               ...         ...  ...  ...  ..   ...    ...   ...
# 6987              NaN         MRB  NaN  NaN   1  0.15   0.07     0
# 6988              NaN         MRB  NaN  NaN   1  0.20   0.10     0
# 6989              NaN         MRB  NaN  NaN   1  0.75   1.16     0
# 6990              NaN         MRB  NaN  NaN   1  1.00   0.85     0
# 6991              NaN         MRB  NaN  NaN   1  0.20   0.10     0
# 6992              NaN         MRB  NaN  NaN   1  0.75   1.17     0
# 6993              NaN         MRB  NaN  NaN   1  1.00   0.85     0
# 6994              NaN         MRB  NaN  NaN   1  0.20   0.05     0
# 6995              NaN         MRB  NaN  NaN   1  0.50   0.05     0
# 6996              NaN         MRB  NaN  NaN   1  0.20   0.02     0
# 6997              NaN         MRB  NaN  NaN   1  0.20   0.02     0
# 6998              NaN         MRB  NaN  NaN   1  0.50   0.66     0
# 6999              NaN         MRB  NaN  NaN   1  0.50   0.66     0
# 7000              NaN         MRB  NaN  NaN   1  0.20   0.02     0
# 7001              NaN         MRB  NaN  NaN   1  0.20   0.02     0
# 7002              NaN         MRB  NaN  NaN   1  0.50   0.66     0
# 7003              NaN         MRB  NaN  NaN   1  0.50   0.66     0
# 7004              NaN         MRB  NaN  NaN   1  0.20   0.02     0
# 7005              NaN         MRB  NaN  NaN   1  0.20   0.02     0
# 7006              NaN         MRB  NaN  NaN   1  0.50   0.66     0
# 7007              NaN         MRB  NaN  NaN   1  0.50   0.66     0
# 7008              NaN         MRB  NaN  NaN   1  0.20   0.02     0
# 7009              NaN         MRB  NaN  NaN   1  0.20   0.02     0
# 7010              NaN         MRB  NaN  NaN   1  0.50   0.66     0
# 7011              NaN         MRB  NaN  NaN   1  0.50   0.66     0
# 7012              NaN         MRB  NaN  NaN   1  0.50   0.48     0
# 7013              NaN         MRB  NaN  NaN   1  0.50   0.48     0
# 7014              NaN         MRB  NaN  NaN   1  0.30   0.02     0
# 7015              NaN         MRB  NaN  NaN   1  0.75   0.02     0
# 7016              NaN         MRB  NaN  NaN   1  1.00   0.02     0
#
#                                          APPLICABILITY
# 0                                                  ALL
# 1                                                  ALL
# 2                                                  ALL
# 3                                                  ALL
# 4                                                  ALL
# 5                                                  ALL
# 6                                                  ALL
# 7                                                  ALL
# 8                                                  ALL
# 9                                           PRE  43165
# 10                                          PRE  43165
# 11                                                 ALL
# 12                                                 ALL
# 13                                          POST 43165
# 14                                          POST 43165
# 15                               PRE  53665\n(92-3062)
# 16                               PRE  53665\n(92-3062)
# 17                               PRE  53665\n(92-3062)
# 18                               PRE  53665\n(92-3062)
# 19                                                 ALL
# 20                                                 ALL
# 21                                                 ALL
# 22                                                 ALL
# 23                                                 ALL
# 24                                                 ALL
# 25                               PRE  53665\n(92-3062)
# 26                               PRE  53665\n(92-3062)
# 27                               PRE  53665\n(92-3062)
# 28                                                 ALL
# 29                                                 ALL
# ...                                                ...
# 6987                                               ALL
# 6988                                               ALL
# 6989                                               ALL
# 6990                                               ALL
# 6991                                               ALL
# 6992                                               ALL
# 6993                                               ALL
# 6994                                               ALL
# 6995                                               ALL
# 6996                                               ALL
# 6997                                               ALL
# 6998                                               ALL
# 6999                                               ALL
# 7000                            A330-200\nOR\nA330-300
# 7001                            A330-200\nOR\nA330-300
# 7002                            A330-200\nOR\nA330-300
# 7003                            A330-200\nOR\nA330-300
# 7004                            A330-200\nOR\nA330-300
# 7005                            A330-200\nOR\nA330-300
# 7006                            A330-200\nOR\nA330-300
# 7007                            A330-200\nOR\nA330-300
# 7008                            A330-200\nOR\nA330-300
# 7009                            A330-200\nOR\nA330-300
# 7010  A330-200\nDOOR TYPE A\nOR\nA330-300\nDOOR TYPE A
# 7011  A330-200\nDOOR TYPE A\nOR\nA330-300\nDOOR TYPE A
# 7012  A330-200\nDOOR TYPE I\nOR\nA330-300\nDOOR TYPE I
# 7013  A330-200\nDOOR TYPE I\nOR\nA330-300\nDOOR TYPE I
# 7014                                         A330-200F
# 7015                                         A330-200F
# 7016                                         A330-200F
#
# [7017 rows x 25 columns]

# %%
# df['SCORE'] = df.apply(lambda x: x['MEN'] * x['TASK'] + x['ACCESS'] + x['PREP'], axis=1)
df.apply(lambda x: type(x['']), axis=1)
# Out:
# 0       <class 'str'>
# 1       <class 'str'>
# 2       <class 'str'>
# 3       <class 'str'>
# 4       <class 'str'>
# 5       <class 'str'>
# 6       <class 'str'>
# 7       <class 'str'>
# 8       <class 'str'>
# 9       <class 'str'>
# 10      <class 'str'>
# 11      <class 'str'>
# 12      <class 'str'>
# 13      <class 'str'>
# 14      <class 'str'>
# 15      <class 'str'>
# 16      <class 'str'>
# 17      <class 'str'>
# 18      <class 'str'>
# 19      <class 'str'>
# 20      <class 'str'>
# 21      <class 'str'>
# 22      <class 'str'>
# 23      <class 'str'>
# 24      <class 'str'>
# 25      <class 'str'>
# 26      <class 'str'>
# 27      <class 'str'>
# 28      <class 'str'>
# 29      <class 'str'>
#             ...
# 6987    <class 'str'>
# 6988    <class 'str'>
# 6989    <class 'str'>
# 6990    <class 'str'>
# 6991    <class 'str'>
# 6992    <class 'str'>
# 6993    <class 'str'>
# 6994    <class 'str'>
# 6995    <class 'str'>
# 6996    <class 'str'>
# 6997    <class 'str'>
# 6998    <class 'str'>
# 6999    <class 'str'>
# 7000    <class 'str'>
# 7001    <class 'str'>
# 7002    <class 'str'>
# 7003    <class 'str'>
# 7004    <class 'str'>
# 7005    <class 'str'>
# 7006    <class 'str'>
# 7007    <class 'str'>
# 7008    <class 'str'>
# 7009    <class 'str'>
# 7010    <class 'str'>
# 7011    <class 'str'>
# 7012    <class 'str'>
# 7013    <class 'str'>
# 7014    <class 'str'>
# 7015    <class 'str'>
# 7016    <class 'str'>
# Length: 7017, dtype: object

# %%
df.sort_values(by='TASKNUMBER')
sdf = df[['TASKNUMBER', 'SCORE']].groupby(by='TASKNUMBER').sum().reset_index()
sdf.to_excel('output1.xlsx')
