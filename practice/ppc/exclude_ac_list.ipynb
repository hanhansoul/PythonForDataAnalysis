# %%
import pandas as pd

# %%
import_list = pd.read_excel('import_ac_list.xls')

# %%
check_list = import_list['机号'].apply(lambda x: 'B-' + str(x).strip())
in_list = pd.Series(['B-1663', 
'B-1818', 
'B-1819', 
'B-1820', 
'B-1883', 
'B-1886', 
'B-1891', 
'B-2300', 
'B-6322', 
'B-6419', 
'B-6448', 
'B-6449', 
'B-6551', 
'B-6697', 
'B-6700', 
'B-8375', 
'B-8378', 
'B-8438', 
'B-8499', 
'B-8605', 
'B-8657', 
'B-8960', 
'B-8961', 
'B-9935', 
'B-1053', 
'B-300D', 
'B-8958', 
'B-6535', 
'B-8468', 
'B-8690'])

# %%
check_list[check_list.isin(in_list)]
# Out:
# 0     B-1053
# 1     B-1663
# 2     B-1818
# 3     B-1819
# 4     B-1883
# 5     B-1886
# 6     B-1891
# 7     B-2300
# 10    B-6322
# 12    B-6419
# 14    B-6448
# 15    B-6449
# 17    B-6535
# 18    B-6551
# 19    B-6697
# 20    B-6700
# 28    B-8375
# 29    B-8378
# 30    B-8438
# 31    B-8468
# 32    B-8499
# 34    B-8605
# 35    B-8657
# 36    B-8690
# 37    B-8958
# 38    B-8960
# 39    B-8961
# 40    B-9935
# 43    B-300D
# Name: 机号, dtype: object

# %%
check_set = set(check_list)
in_set = set(in_list)

# %%
check_set - in_set
# Out:
# {'B-5923',
#  'B-5929',
#  'B-6387',
#  'B-6433',
#  'B-6517',
#  'B-6719',
#  'B-6778',
#  'B-6810',
#  'B-6953',
#  'B-6955',
#  'B-6957',
#  'B-6968',
#  'B-8589',
#  'B-9936',
#  'B-9967'}

# %%
in_set - check_set
# Out:
# {'B-1820'}

# %%
pd.concat([check_list, in_list], axis=1)
# Out:
#         机号       0
# 0   B-1053  B-1663
# 1   B-1663  B-1818
# 2   B-1818  B-1819
# 3   B-1819  B-1820
# 4   B-1883  B-1883
# 5   B-1886  B-1886
# 6   B-1891  B-1891
# 7   B-2300  B-2300
# 8   B-5923  B-6322
# 9   B-5929  B-6419
# 10  B-6322  B-6448
# 11  B-6387  B-6449
# 12  B-6419  B-6551
# 13  B-6433  B-6697
# 14  B-6448  B-6700
# 15  B-6449  B-8375
# 16  B-6517  B-8378
# 17  B-6535  B-8438
# 18  B-6551  B-8499
# 19  B-6697  B-8605
# 20  B-6700  B-8657
# 21  B-6719  B-8960
# 22  B-6778  B-8961
# 23  B-6810  B-9935
# 24  B-6953  B-1053
# 25  B-6955  B-300D
# 26  B-6957  B-8958
# 27  B-6968  B-6535
# 28  B-8375  B-8468
# 29  B-8378  B-8690
# 30  B-8438     NaN
# 31  B-8468     NaN
# 32  B-8499     NaN
# 33  B-8589     NaN
# 34  B-8605     NaN
# 35  B-8657     NaN
# 36  B-8690     NaN
# 37  B-8958     NaN
# 38  B-8960     NaN
# 39  B-8961     NaN
# 40  B-9935     NaN
# 41  B-9936     NaN
# 42  B-9967     NaN
# 43  B-300D     NaN
