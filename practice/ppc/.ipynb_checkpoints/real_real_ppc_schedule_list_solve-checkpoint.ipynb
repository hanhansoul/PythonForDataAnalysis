# %%
import pandas as pd

# %%
# 读入数据
fmct = pd.read_excel('FMCT.xlsx')
fmop = pd.read_excel('FMOP.xlsx')
fmvs = pd.read_excel('FMVS.xlsx')
fmpg = pd.read_excel('FMPG.xlsx', dtype=str).replace('nan', '')
frav = pd.read_excel('FRAV.xlsx')

# %%
# 重命名参考表列名
nfmvs = pd.DataFrame(fmvs[['VSAPPL', 'VSNUMDOC', 'VSTITRE']])
nfmct = pd.DataFrame(fmct[['CTAPPL', 'CTNUMDOC', 'CTTITRE']])
nfmop = pd.DataFrame(fmop[['OPAPPL', 'OPNUMDOC', 'OPTITRE']])
nfmvs.rename(columns={'VSAPPL': 'PROTOCOL', 'VSNUMDOC': 'REFERENCE', 'VSTITRE': 'TITLE'}, inplace=True)
nfmct.rename(columns={'CTAPPL': 'PROTOCOL', 'CTNUMDOC': 'REFERENCE', 'CTTITRE': 'TITLE'}, inplace=True)
nfmop.rename(columns={'OPAPPL': 'PROTOCOL', 'OPNUMDOC': 'REFERENCE', 'OPTITRE': 'TITLE'}, inplace=True)
docs = {'1': nfmvs, '2': nfmct, '3': nfmop}

# %%
# 日期格式化
def performace_dates_join(years, months, days):
    ll = []
    for y, m, d in zip(years, months, days):
        ll.append(y + m + d)
    return pd.Series(ll)

def deadline_dates_join(years, months, days):
    ll = []
    for y, m, d in zip(years, months, days):
        if y != '' and m != '' and d != '':
            ll.append(y + '-' + m + '-' + d)
        else:
            ll.append('')
    return pd.Series(ll)

# %%
frav = frav.applymap(lambda x: x.strip())
fmpg['AVOFFICIEL'] = fmpg.merge(frav[['AVNUMAP', 'AVOFFICIEL']], how='left', left_on='PGNUMAP', right_on='AVNUMAP')['AVOFFICIEL']

# %%
# 按导出列名重构fmpg
d = {'AC': fmpg['AVOFFICIEL'].str.strip(),
     'PROTOCOL': fmpg['PGAPPL'].str.strip(),
     'PGCODTE': fmpg['PGCODTE'],
     'REFERENCE': fmpg['PGNUMDOC'].str.strip(),
     'STATUS': fmpg['PGSIT'].str.strip(),
     'PERFORMACE_DOC': fmpg['PGAPPDOC1'].str.strip() + fmpg['PGAPPDOC2'].str.strip(),
     'PERFORMACE_DATE': performace_dates_join(fmpg['PGAPPA4'].str.strip(), fmpg['PGAPPMM'].str.strip(), fmpg['PGAPPJJ'].str.strip()),
     'FH_DEADLINE': fmpg['PGPRVH'],
     'CY_DEADLINE': fmpg['PGPRVC'],
     'DEADLINE_DOC': fmpg['PGPRVDOC1'].str.strip() + fmpg['PGPRVDOC2'].str.strip(),
     'DEADLINE_DATE': deadline_dates_join(fmpg['PGPRVA4'].str.strip(), fmpg['PGPRVMM'].str.strip(), fmpg['PGPRVJJ'].str.strip())
    }

nfmpg = pd.DataFrame(d, columns=['AC', 'PROTOCOL', 'PGCODTE', 'REFERENCE', 'STATUS', 'PERFORMACE_DOC', 'PERFORMACE_DATE', 
                              'FH_DEADLINE', 'CY_DEADLINE', 'DEADLINE_DOC', 'DEADLINE_DATE'])

# %%
# 根据doc类型分组
groupbycode = nfmpg.groupby(nfmpg['PGCODTE'])
dfs = {}
for k, v in groupbycode:
    dfs[k] = pd.DataFrame(v)

# %%
# 根据REFERENCE获取TITLE
mindex = ['AC', 'PROTOCOL', 'PGCODTE', 'REFERENCE', 'TITLE', 'STATUS', 'PERFORMACE_DOC', 'DEADLINE_DOC',
          'FH_DEADLINE', 'CY_DEADLINE', 'PERFORMACE_DATE', 'DEADLINE_DATE']

merged_dfs = {}
for k, v in dfs.items():
    merged_dfs[k] = pd.merge(v, docs[k], on=['PROTOCOL', 'REFERENCE'], how='left')[mindex]

# %%
merged_dfs['2']

output_df = merged_dfs['2']
output_df.to_excel('output_20190410.xlsx', columns=['AC', 'PROTOCOL', 'REFERENCE', 'TITLE', 'PERFORMACE_DOC', 'DEADLINE_DOC',
          'FH_DEADLINE', 'CY_DEADLINE', 'PERFORMACE_DATE', 'DEADLINE_DATE'])
# Out:
#            AC PROTOCOL PGCODTE         REFERENCE  \
# 0      B-6517     A330       2       ZL-100-01-2
# 1      B-6517     A330       2       ZL-110-01-1
# 2      B-6517     A330       2       ZL-121-01-1
# 3      B-6517     A330       2       ZL-121-02-1
# 4      B-6517     A330       2       ZL-123-01-1
# 5      B-6517     A330       2       ZL-131-01-1
# 6      B-6517     A330       2       ZL-131-02-2
# 7      B-6517     A330       2       ZL-131-03-1
# 8      B-6517     A330       2       ZL-133-01-1
# 9      B-6517     A330       2       ZL-137-01-1
# 10     B-6517     A330       2       ZL-141-01-1
# 11     B-6517     A330       2       ZL-143-01-1
# 12     B-6517     A330       2       ZL-145-01-1
# 13     B-6517     A330       2       ZL-147-01-1
# 14     B-6517     A330       2       ZL-149-05-1
# 15     B-6517     A330       2       ZL-151-01-1
# 16     B-6517     A330       2       ZL-151-02-3
# 17     B-6517     A330       2       ZL-151-03-1
# 18     B-6517     A330       2       ZL-153-01-1
# 19     B-6517     A330       2       ZL-161-01-1
# 20     B-6517     A330       2       ZL-161-02-1
# 21     B-6517     A330       2       ZL-161-03-1
# 22     B-6517     A330       2       ZL-163-01-1
# 23     B-6517     A330       2       ZL-171-01-1
# 24     B-6517     A330       2       ZL-171-02-1
# 25     B-6517     A330       2       ZL-191-01-1
# 26     B-6517     A330       2       ZL-191-02-1
# 27     B-6517     A330       2       ZL-193-01-1
# 28     B-6517     A330       2       ZL-193-02-1
# 29     B-6517     A330       2       ZL-195-01-1
# ...       ...      ...     ...               ...
# 17456  B-9936     A320       2       53ZB85-50-6
# 17457  B-9936     A320       2       545000-06-1
# 17458  B-9936     A320       2       534155-01-2
# 17459  B-9936     A320       2       533130-01-1
# 17460  B-9936     A320       2       531111-02-1
# 17461  B-9936     A320       2      572161-01-11
# 17462  B-9936     A320       2       535162-09-2
# 17463  B-9936     A320       2       576103-01-4
# 17464  B-9936     A320       2       521000-18-1
# 17465  B-9936     A320       2       572178-01-1
# 17466  B-9936     A320       2       572179-01-1
# 17467  B-9936     A320       2       572065-01-1
# 17468  B-9936     A320       2       572066-01-1
# 17469  B-9936     A320       2       335100-11-1
# 17470  B-9936     A320       2       281100-05-1
# 17471  B-9936     A320       2       281100-06-1
# 17472  B-9936     A320       2       361251-01-3
# 17473  B-9936     A320       2       274451-02-2
# 17474  B-9936     A320       2       335100-10-1
# 17475  B-9936     A320       2       271400-01-1
# 17476  B-9936     A320       2       273400-01-1
# 17477  B-9936     A320       2       282400-02-1
# 17478  B-9936     A320       2       271400-03-1
# 17479  B-9936     A320       2       273400-03-1
# 17480  B-9936     A320       2       272400-06-1
# 17481  B-9936     A320       2       324000-16-1
# 17482  B-9936     A320       2       78ZB16-03-1
# 17483  B-9936     A320       2       53ZB85-92-3
# 17484  B-9936     A320       2  EOA320-2018-055R
# 17485  B-9936     A320       2       21ZB01-03-1
#
#                                           TITLE STATUS PERFORMACE_DOC  \
# 0                        LOWER HALF OF FUSELAGE      O     CS00956881
# 1                                        RADOME      O     CS00951393
# 2                          AVIONICS COMPARTMENT      O     CS00956881
# 3                          AVIONICS COMPARTMENT      O     CS00951393
# 4                                NOSE GEAR WELL      O     CS00956881
# 5                     FORWARD CARGO COMPARTMENT      O     CS00960912
# 6                     FORWARD CARGO COMPARTMENT      O     CS00951393
# 7                     FORWARD CARGO COMPARTMENT      O
# 8               BAY UNDER FWD CARGO COMPARTMENT      O     CS00951393
# 9              BAY BEHIND FWD CARGO COMPARTMENT      O     CS00951393
# 10                              CENTER WING BOX      O
# 11                      AREA BETWEEN KEEL BEAMS      O
# 12                       ZONE UNDER CABIN FLOOR      O
# 13           MLG WELL AND HYDRAULIC COMPARTMENT      O     CS00960912
# 14                              CENTER LINE BAY      O
# 15                        AFT CARGO COMPARTMENT      O     CS00960912
# 16                        AFT CARGO COMPARTMENT      O     CS00951393
# 17                        AFT CARGO COMPARTMENT      O
# 18              BAY UNDER AFT CARGO COMPARTMENT      O     CS00951393
# 19                       BULK CARGO COMPARTMENT      O     CS00960912
# 20                       BULK CARGO COMPARTMENT      O     CS00951393
# 21                       BULK CARGO COMPARTMENT      O
# 22             BAY UNDER BULK CARGO COMPARTMENT      O     CS00951393
# 23             AFT CABIN UNDERFLOOR COMPARTMENT      O     CS00956881
# 24             AFT CABIN UNDERFLOOR COMPARTMENT      O     CS00951393
# 25           AIR CONDITIONING COMPT AND FAIRING      O     CS00951393
# 26           AIR CONDITIONING COMPT AND FAIRING      O     CS00951393
# 27     AIR CONDITIONING COMPARTMENT AND FAIRING      O     CS00951393
# 28     AIR CONDITIONING COMPARTMENT AND FAIRING      O     CS00951393
# 29           HYDRAULIC COMPARTMENT AND FAIRINGS      O     CS00960912
# ...                                         ...    ...            ...
# 17456                         DOOR STOP FITTING      O
# 17457                                    PYLONS      O
# 17458            AFT CARGO DOOR ECCENTRIC BOLTS      O
# 17459          ANTI COLLISION LIGHT SKIN CUTOUT      O
# 17460                   AVIONICS DOORS SURROUND      O
# 17461                            MAIN STRUCTURE      O
# 17462              FIN/FUSELAGE ATTACH FITTINGS      O
# 17463                                   AILERON      O
# 17464                       PASSENGER/CREW DOOR      O
# 17465                                OUTER WING      O
# 17466                                OUTER WING      O
# 17467         OUTER WING TOP SKIN LOWER SURFACE      O
# 17468         OUTER WING TOP SKIN LOWER SURFACE      O
# 17469                  CABIN EMERGENCY LIGHTING      O
# 17470                                     TANKS      O     CS00960420
# 17471                                     TANKS      O     CS00960420
# 17472                     APU BLEED CHECK VALVE      O
