# %%
import pandas as pd

df = pd.read_excel('input.xls', header=0)
df.rename(columns=lambda x: 'attr%d' % x, inplace=True)
df = df.reindex(columns=['attr1', 'attr2', 'attr3', 'attr4', 
                         'sid1', 'sid2', 'sid3', 'sid4', 'display'])
df['attr1'].replace({'运行能力': '飞机能力'}, inplace=True)
# df[['attr1', 'attr2']].fillna(method='ffill', inplace=True)
df['attr1'].fillna(method='ffill', inplace=True)
df['attr2'].fillna(method='ffill', inplace=True)

mapping = {'全舱': '客舱构型及氧气系统',
  '公务舱': '客舱构型及氧气系统',
  '厕所': '客舱构型及氧气系统',
  '厨房': '客舱构型及氧气系统',
  '发动机和APU': '机型/发动机及APU型号/鲨鳍小翼',
  '娱乐系统': '客舱构型及氧气系统',
  '客舱': '客舱构型及氧气系统',
  '导航': '飞机能力及导航设备',
  '翼梢小翼': '机型/发动机及APU型号/鲨鳍小翼',
  '应急设备': '客舱构型及氧气系统',
  '机型/发动机型号': '机型/发动机及APU型号/鲨鳍小翼',
  '机载维修系统': None,
  '氧气': '客舱构型及氧气系统',
  '燃油': '飞机重量及燃油容积',
  '经济舱': '客舱构型及氧气系统',
  '计量单位': '飞机能力及导航设备',
  '译码和参数': '通信设备/译码与参数',
  '货舱': '货舱舱构型',
  '轮胎刹车': None,
  '通信': '通信设备/译码与参数',
  '重量信息': '飞机重量及燃油容积',
  '防冰': None,
  '飞机能力': '飞机能力及导航设备'}

df['attr4'] = df['attr1'].replace(mapping)

def solve(frame, ii, origin):
    if ii > 3:
        return
    attr, sid = 'attr' + str(ii), 'sid' + str(ii)
    series = frame[attr].drop_duplicates()
    mapping = {}
    for i, x in enumerate(series):
        solve(frame[frame[attr] == x], ii + 1, origin)
        mapping[x] = str(i + 1)
    origin[sid].iloc[frame.index] = frame[attr].replace(mapping)
    
solve(df, 1, df)
df
# Out:
# e:\applications\python35\lib\site-packages\pandas\core\indexing.py:194: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
#        attr1                         attr2                  attr3  \
# 0         机型                      A350-941                    NaN
# 1       飞机能力                     ADS-B OUT                    NaN
# 2       飞机能力                      ADS-B IN                    NaN
# 3       飞机能力                        RNP AR                    0.1
# 4       飞机能力                         RNP 1                    NaN
# 5       飞机能力                         RNP 4                    NaN
# 6       飞机能力                        RNP 10                    NaN
# 7       飞机能力                      RNP APCH                    NaN
# 8       飞机能力                      RNAV 1&2                    NaN
# 9       飞机能力                        RNAV 5                    NaN
# 10      飞机能力                          RVSM                    NaN
# 11      飞机能力                          延伸跨水                    NaN
# 12      飞机能力                        CAT II                    NaN
# 13      飞机能力                         高高原运行                    NaN
# 14      飞机能力                   ETOPS 370分钟                    NaN
# 15      飞机能力                           HUD                    NaN
# 16      飞机能力                         CPDLC                    NaN
# 17      飞机能力                          ROPS                    NaN
# 18      飞机能力                           ANF                    NaN
# 19      飞机能力                           BTV                    NaN
# 20      飞机能力                           GLS                    NaN
# 21      飞机能力                           SLS                    NaN
# 22      飞机能力                           BTV                    NaN
# 23      飞机能力                         QFE设定                    NaN
# 24      计量单位                            米制                    NaN
# 25      重量信息                          MTOW                   275吨
# 26      重量信息                          MLW                    207吨
# 27      重量信息                         MZFW                  195.7吨
# 28      重量信息                          MTW                  275.9吨
# 29      重量信息  Minimun Weight   for Takeoff                   144吨
# ..       ...                           ...                    ...
# 77        货舱                       散货舱通风系统                    NaN
# 78        燃油                            容积  140 795 L/ 110 523 kg
# 79        燃油                          抛油系统                    NaN
# 80        防冰                          防冰探头                    NaN
# 81      数据装载                       机载OMS系统                    NaN
# 82      数据装载                      通过MDDU装载                    NaN
# 83     译码和参数                     WDAR/WEFA                   WDAR
# 84     译码和参数                     WDAR/WEFA                   WQAR
# 85     译码和参数                     WDAR/WEFA            虚拟QAR集成在ASF
# 86     译码和参数                          SIM卡                     2G
# 87     译码和参数                          SIM卡                  3G/4G
# 88      轮胎刹车                          刹车风扇                    NaN
# 89        导航                         GPS功能                    MMR
# 90        导航                         雷达收发机                     2台
# 91        导航                        TCAS版本                    7.0
# 92        导航                        TCAS版本                    7.1
# 93        导航                        TCAS厂家              HONEYWELL
# 94        导航                        TAWS厂家              HONEYWELL
# 95        导航                        ADF收发机                     2台
# 96        导航                    AP/FD TCAS                    NaN
# 97        氧气                          机组氧气                 专用充气接头
# 98        氧气                        旅客氧气系统                分布式独立气瓶
# 99      维护系统                          ASFC                     1台
# 100     维护系统                          ASFC                     2台
# 101       小翼                          翼梢小翼                    NaN
# 102  发动机和APU                         发动机型号          TRENT XWB-84
# 103  发动机和APU                       发动机制造厂家                   罗罗RR
# 104  发动机和APU                         APU型号                HGT1700
# 105  发动机和APU                       APU制造厂家              HONEYWELL
# 106  发动机和APU                     发动机和APU滑油                BP 2197
#
#                  attr4 sid1 sid2 sid3  sid4  display
# 0                   机型    1    1    1   NaN      NaN
# 1            飞机能力及导航设备    2    1    1   NaN      NaN
# 2            飞机能力及导航设备    2    2    1   NaN      NaN
# 3            飞机能力及导航设备    2    3    1   NaN      NaN
# 4            飞机能力及导航设备    2    4    1   NaN      NaN
# 5            飞机能力及导航设备    2    5    1   NaN      NaN
# 6            飞机能力及导航设备    2    6    1   NaN      NaN
# 7            飞机能力及导航设备    2    7    1   NaN      NaN
# 8            飞机能力及导航设备    2    8    1   NaN      NaN
# 9            飞机能力及导航设备    2    9    1   NaN      NaN
# 10           飞机能力及导航设备    2   10    1   NaN      NaN
# 11           飞机能力及导航设备    2   11    1   NaN      NaN
# 12           飞机能力及导航设备    2   12    1   NaN      NaN
# 13           飞机能力及导航设备    2   13    1   NaN      NaN
# 14           飞机能力及导航设备    2   14    1   NaN      NaN
# 15           飞机能力及导航设备    2   15    1   NaN      NaN
# 16           飞机能力及导航设备    2   16    1   NaN      NaN
# 17           飞机能力及导航设备    2   17    1   NaN      NaN
# 18           飞机能力及导航设备    2   18    1   NaN      NaN
# 19           飞机能力及导航设备    2   19    1   NaN      NaN
# 20           飞机能力及导航设备    2   20    1   NaN      NaN
# 21           飞机能力及导航设备    2   21    1   NaN      NaN
# 22           飞机能力及导航设备    2   19    1   NaN      NaN
# 23           飞机能力及导航设备    2   22    1   NaN      NaN
# 24           飞机能力及导航设备    3    1    1   NaN      NaN
# 25           飞机重量及燃油容积    4    1    1   NaN      NaN
# 26           飞机重量及燃油容积    4    2    1   NaN      NaN
# 27           飞机重量及燃油容积    4    3    1   NaN      NaN
# 28           飞机重量及燃油容积    4    4    1   NaN      NaN
# 29           飞机重量及燃油容积    4    5    1   NaN      NaN
# ..                 ...  ...  ...  ...   ...      ...
# 77               货舱舱构型   14    4    1   NaN      NaN
# 78           飞机重量及燃油容积   15    1    1   NaN      NaN
# 79           飞机重量及燃油容积   15    2    1   NaN      NaN
# 80                None   16    1    1   NaN      NaN
# 81                数据装载   17    1    1   NaN      NaN
# 82                数据装载   17    2    1   NaN      NaN
# 83          通信设备/译码与参数   18    1    1   NaN      NaN
# 84          通信设备/译码与参数   18    1    2   NaN      NaN
# 85          通信设备/译码与参数   18    1    3   NaN      NaN
# 86          通信设备/译码与参数   18    2    1   NaN      NaN
# 87          通信设备/译码与参数   18    2    2   NaN      NaN
# 88                None   19    1    1   NaN      NaN
# 89           飞机能力及导航设备   20    1    1   NaN      NaN
# 90           飞机能力及导航设备   20    2    1   NaN      NaN
# 91           飞机能力及导航设备   20    3    1   NaN      NaN
# 92           飞机能力及导航设备   20    3    2   NaN      NaN
# 93           飞机能力及导航设备   20    4    1   NaN      NaN
# 94           飞机能力及导航设备   20    5    1   NaN      NaN
# 95           飞机能力及导航设备   20    6    1   NaN      NaN
# 96           飞机能力及导航设备   20    7    1   NaN      NaN
# 97           客舱构型及氧气系统   21    1    1   NaN      NaN
# 98           客舱构型及氧气系统   21    2    1   NaN      NaN
# 99                维护系统   22    1    1   NaN      NaN
# 100               维护系统   22    1    2   NaN      NaN
# 101                 小翼   23    1    1   NaN      NaN
# 102  机型/发动机及APU型号/鲨鳍小翼   24    1    1   NaN      NaN
# 103  机型/发动机及APU型号/鲨鳍小翼   24    2    1   NaN      NaN
# 104  机型/发动机及APU型号/鲨鳍小翼   24    3    1   NaN      NaN
# 105  机型/发动机及APU型号/鲨鳍小翼   24    4    1   NaN      NaN
# 106  机型/发动机及APU型号/鲨鳍小翼   24    5    1   NaN      NaN
#
# [107 rows x 9 columns]

# %%
df.to_excel('output.xlsx')

# %%
import pymssql

conn = pymssql.connect(host='172.18.8.241', 
                       port=1433, 
                       user='sa', 
                       password='Scaljw@2016', 
                       database='AMIS-CSC')
pd.to_sql('[AMIS-CSC].[dbo].[ACConfDiffConfInfoA350]', 
         conn, 
         if_exists='append',
         index)
